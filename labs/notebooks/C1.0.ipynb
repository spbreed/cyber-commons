# %% [markdown]
# ### C1.0 · Start here — the evolution of non-deterministic threat simulation
#
# This lesson has no procedure to run — it is read. [Open it on Cyber Commons](https://spbreed.github.io/cyber-commons/lessons/C1.0.html).
